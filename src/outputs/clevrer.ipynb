# %% [markdown]
# # Q1
# ```
# # matching videos: 10000, # matching video frames: 1280000
# ingest_videos_fast took time: 0.035s
# region graph: [defaultdict(<class 'dict'>, {0: {'shape': 'cube'}, 1: {'shape': 'sphere'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 7378, # matching video frames: 814638
# add_predicate_object took time: 393.016s
# g1: [defaultdict(<class 'dict'>, {0: {'shape': 'cube', 'color': 'red', 'material': 'metal'}, 1: {'shape': 'sphere', 'color': 'gray'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 158, # matching video frames: 15287
# add_predicate_attribute took time: 294.882s
# g1: [defaultdict(<class 'dict'>, {0: {'shape': 'cube', 'color': 'red', 'material': 'metal'}, 1: {'shape': 'sphere', 'color': 'gray'}}), defaultdict(<class 'dict'>, {0: {'sub_id': 0, 'obj_id': 1, 'rel_name': 'collision'}})]
# # matching videos: 47, # matching video frames: 47
# add_predicate_relationship took time: 6.212s
# region graph: [defaultdict(<class 'dict'>, {2: {'shape': 'cube'}, 3: {'shape': 'cylinder'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 7311, # matching video frames: 833428
# add_predicate_object took time: 388.944s
# g1: [defaultdict(<class 'dict'>, {2: {'shape': 'cube', 'color': 'red', 'material': 'metal'}, 3: {'shape': 'cylinder'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 753, # matching video frames: 81884
# add_predicate_attribute took time: 301.821s
# g1: [defaultdict(<class 'dict'>, {2: {'shape': 'cube', 'color': 'red', 'material': 'metal'}, 3: {'shape': 'cylinder'}}), defaultdict(<class 'dict'>, {1: {'sub_id': 2, 'obj_id': 3, 'rel_name': 'collision'}})]
# # matching videos: 280, # matching video frames: 315
# add_predicate_relationship took time: 26.840s
# seqence of region graphs: ([defaultdict(<class 'dict'>, {0: {'shape': 'cube', 'color': 'red', 'material': 'metal'}, 1: {'shape': 'sphere', 'color': 'gray'}}), defaultdict(<class 'dict'>, {0: {'sub_id': 0, 'obj_id': 1, 'rel_name': 'collision'}})], [defaultdict(<class 'dict'>, {2: {'shape': 'cube', 'color': 'red', 'material': 'metal'}, 3: {'shape': 'cylinder'}}), defaultdict(<class 'dict'>, {1: {'sub_id': 2, 'obj_id': 3, 'rel_name': 'collision'}})])
# # matching videos: 5, # matching video segments: 5
# add_predicate_seq_of_region_graphs took time: 0.000s
# outputs: defaultdict(<class 'list'>, {6189: [[47, 66]], 8601: [[58, 62]], 8506: [[48, 68]], 3044: [[41, 47]], 3715: [[50, 106]]})
# visualize_outputs took time: 3.023s
# ```
#
# # Q1 noisy model (acc=0.9 for attribute model)
# ```
# # matching videos: 10000, # matching video frames: 1280000
# ingest_videos_fast took time: 0.025s
# region graph: [defaultdict(<class 'dict'>, {0: {'p_shape': 'cube'}, 1: {'p_shape': 'sphere'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 7378, # matching video frames: 814638
# add_predicate_object took time: 241.911s
# g1: [defaultdict(<class 'dict'>, {0: {'p_shape': 'cube', 'n_color_red': <function color_red at 0x7f3f988da700>, 'n_material_metal': <function material_metal at 0x7f3f988da820>}, 1: {'p_shape': 'sphere', 'n_color_gray': <function color_gray at 0x7f3f988da790>}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 388, # matching video frames: 38246
# add_predicate_attribute_proxy took time: 179.530s
# g1: [defaultdict(<class 'dict'>, {0: {'p_shape': 'cube', 'n_color_red': <function color_red at 0x7f3f988da700>, 'n_material_metal': <function material_metal at 0x7f3f988da820>}, 1: {'p_shape': 'sphere', 'n_color_gray': <function color_gray at 0x7f3f988da790>}}), defaultdict(<class 'dict'>, {0: {'sub_id': 0, 'obj_id': 1, 'rel_name': 'p_collision'}})]
# # matching videos: 37, # matching video frames: 38
# add_predicate_relationship_proxy took time: 6.344s
# region graph: [defaultdict(<class 'dict'>, {2: {'p_shape': 'cube'}, 3: {'p_shape': 'cylinder'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 7311, # matching video frames: 833428
# add_predicate_object took time: 250.976s
# g1: [defaultdict(<class 'dict'>, {2: {'p_shape': 'cube', 'n_color_red': <function color_red at 0x7f3f988da700>, 'n_material_metal': <function material_metal at 0x7f3f988da820>}, 3: {'p_shape': 'cylinder'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 1228, # matching video frames: 131763
# add_predicate_attribute_proxy took time: 201.089s
# g1: [defaultdict(<class 'dict'>, {2: {'p_shape': 'cube', 'n_color_red': <function color_red at 0x7f3f988da700>, 'n_material_metal': <function material_metal at 0x7f3f988da820>}, 3: {'p_shape': 'cylinder'}}), defaultdict(<class 'dict'>, {1: {'sub_id': 2, 'obj_id': 3, 'rel_name': 'p_collision'}})]
# # matching videos: 227, # matching video frames: 253
# add_predicate_relationship_proxy took time: 20.544s
# seqence of region graphs: ([defaultdict(<class 'dict'>, {0: {'p_shape': 'cube', 'n_color_red': <function color_red at 0x7f3f988da700>, 'n_material_metal': <function material_metal at 0x7f3f988da820>}, 1: {'p_shape': 'sphere', 'n_color_gray': <function color_gray at 0x7f3f988da790>}}), defaultdict(<class 'dict'>, {0: {'sub_id': 0, 'obj_id': 1, 'rel_name': 'p_collision'}})], [defaultdict(<class 'dict'>, {2: {'p_shape': 'cube', 'n_color_red': <function color_red at 0x7f3f988da700>, 'n_material_metal': <function material_metal at 0x7f3f988da820>}, 3: {'p_shape': 'cylinder'}}), defaultdict(<class 'dict'>, {1: {'sub_id': 2, 'obj_id': 3, 'rel_name': 'p_collision'}})])
# # matching videos: 5, # matching video segments: 5
# add_predicate_seq_of_region_graphs took time: 0.000s
# outputs: defaultdict(<class 'list'>, {6189: [[47, 66]], 8296: [[27, 66]], 8601: [[58, 62]], 8506: [[48, 68]], 3044: [[41, 47]]})
# visualize_outputs took time: 1.118s
# ```
#
# # Q1 noisy model (acc=0.999 for collision model)
# ```
# # matching videos: 10000, # matching video frames: 1280000
# ingest_videos_fast took time: 0.024s
# region graph: [defaultdict(<class 'dict'>, {0: {'p_shape': 'cube'}, 1: {'p_shape': 'sphere'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 7378, # matching video frames: 814638
# add_predicate_object took time: 231.603s
# g1: [defaultdict(<class 'dict'>, {0: {'p_shape': 'cube', 'p_color': 'red', 'p_material': 'metal'}, 1: {'p_shape': 'sphere', 'p_color': 'gray'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 158, # matching video frames: 15287
# add_predicate_attribute_proxy took time: 171.923s
# g1: [defaultdict(<class 'dict'>, {0: {'p_shape': 'cube', 'p_color': 'red', 'p_material': 'metal'}, 1: {'p_shape': 'sphere', 'p_color': 'gray'}}), defaultdict(<class 'dict'>, {0: {'sub_id': 0, 'obj_id': 1, 'rel_name': 'n_collision', 'rel_object': <function collision at 0x7f943e255820>}})]
# # matching videos: 31, # matching video frames: 33
# add_predicate_relationship_proxy took time: 2.304s
# region graph: [defaultdict(<class 'dict'>, {2: {'p_shape': 'cube'}, 3: {'p_shape': 'cylinder'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 7311, # matching video frames: 833428
# add_predicate_object took time: 228.543s
# g1: [defaultdict(<class 'dict'>, {2: {'p_shape': 'cube', 'p_color': 'red', 'p_material': 'metal'}, 3: {'p_shape': 'cylinder'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 753, # matching video frames: 81884
# add_predicate_attribute_proxy took time: 174.456s
# g1: [defaultdict(<class 'dict'>, {2: {'p_shape': 'cube', 'p_color': 'red', 'p_material': 'metal'}, 3: {'p_shape': 'cylinder'}}), defaultdict(<class 'dict'>, {1: {'sub_id': 2, 'obj_id': 3, 'rel_name': 'n_collision', 'rel_object': <function collision at 0x7f943e255820>}})]
# # matching videos: 246, # matching video frames: 278
# add_predicate_relationship_proxy took time: 15.687s
# seqence of region graphs: ([defaultdict(<class 'dict'>, {0: {'p_shape': 'cube', 'p_color': 'red', 'p_material': 'metal'}, 1: {'p_shape': 'sphere', 'p_color': 'gray'}}), defaultdict(<class 'dict'>, {0: {'sub_id': 0, 'obj_id': 1, 'rel_name': 'n_collision', 'rel_object': <function collision at 0x7f943e255820>}})], [defaultdict(<class 'dict'>, {2: {'p_shape': 'cube', 'p_color': 'red', 'p_material': 'metal'}, 3: {'p_shape': 'cylinder'}}), defaultdict(<class 'dict'>, {1: {'sub_id': 2, 'obj_id': 3, 'rel_name': 'n_collision', 'rel_object': <function collision at 0x7f943e255820>}})])
# # matching videos: 2, # matching video segments: 2
# add_predicate_seq_of_region_graphs took time: 0.000s
# outputs: defaultdict(<class 'list'>, {1268: [[91, 112]], 5344: [[66, 110]]})
# ```
#
# # Q2
# ```
# # matching videos: 10000, # matching video frames: 1280000
# ingest_videos_fast took time: 0.025s
# region graph: [defaultdict(<class 'dict'>, {0: {'shape': 'cube'}, 1: {'shape': 'sphere'}, 2: {'shape': 'cube'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 3859, # matching video frames: 383812
# add_predicate_object took time: 391.969s
# g1: [defaultdict(<class 'dict'>, {0: {'shape': 'cube', 'color': 'red'}, 1: {'shape': 'sphere', 'color': 'gray'}, 2: {'shape': 'cube'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 208, # matching video frames: 19343
# add_predicate_attribute took time: 152.380s
# g1: [defaultdict(<class 'dict'>, {0: {'shape': 'cube', 'color': 'red'}, 1: {'shape': 'sphere', 'color': 'gray'}, 2: {'shape': 'cube'}}), defaultdict(<class 'dict'>, {0: {'sub_id': 0, 'obj_id': 1, 'rel_name': 'collision'}})]
# # matching videos: 57, # matching video frames: 59
# add_predicate_relationship took time: 7.949s
# region graph: [defaultdict(<class 'dict'>, {3: {'shape': 'cube'}, 4: {'shape': 'cylinder'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 7311, # matching video frames: 833428
# add_predicate_object took time: 392.124s
# g1: [defaultdict(<class 'dict'>, {3: {'shape': 'cube', 'color': 'red'}, 4: {'shape': 'cylinder', 'material': 'metal'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 966, # matching video frames: 101790
# add_predicate_attribute took time: 291.312s
# g1: [defaultdict(<class 'dict'>, {3: {'shape': 'cube', 'color': 'red'}, 4: {'shape': 'cylinder', 'material': 'metal'}}), defaultdict(<class 'dict'>, {1: {'sub_id': 3, 'obj_id': 4, 'rel_name': 'collision'}})]
# # matching videos: 271, # matching video frames: 284
# add_predicate_relationship took time: 36.258s
# seqence of region graphs: ([defaultdict(<class 'dict'>, {0: {'shape': 'cube', 'color': 'red'}, 1: {'shape': 'sphere', 'color': 'gray'}, 2: {'shape': 'cube'}}), defaultdict(<class 'dict'>, {0: {'sub_id': 0, 'obj_id': 1, 'rel_name': 'collision'}})], [defaultdict(<class 'dict'>, {3: {'shape': 'cube', 'color': 'red'}, 4: {'shape': 'cylinder', 'material': 'metal'}}), defaultdict(<class 'dict'>, {1: {'sub_id': 3, 'obj_id': 4, 'rel_name': 'collision'}})])
# # matching videos: 1, # matching video segments: 1
# add_predicate_seq_of_region_graphs took time: 0.000s
# outputs: defaultdict(<class 'list'>, {1109: [[68, 82]]})
# visualize_outputs took time: 0.602s
# ```
#
# # Q3
# ```
# # matching videos: 10000, # matching video frames: 1280000
# ingest_videos_fast took time: 0.028s
# region graph: [defaultdict(<class 'dict'>, {0: {'shape': 'cylinder'}, 1: {'shape': 'sphere'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 7695, # matching video frames: 855739
# add_predicate_object took time: 384.575s
# g1: [defaultdict(<class 'dict'>, {0: {'shape': 'cylinder', 'material': 'rubber'}, 1: {'shape': 'sphere', 'color': 'purple', 'material': 'metal'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 571, # matching video frames: 56620
# add_predicate_attribute took time: 332.215s
# g1: [defaultdict(<class 'dict'>, {0: {'shape': 'cylinder', 'material': 'rubber'}, 1: {'shape': 'sphere', 'color': 'purple', 'material': 'metal'}}), defaultdict(<class 'dict'>, {0: {'sub_id': 0, 'obj_id': 1, 'rel_name': 'collision'}})]
# # matching videos: 185, # matching video frames: 200
# add_predicate_relationship took time: 21.337s
# region graph: [defaultdict(<class 'dict'>, {2: {'shape': 'cylinder'}, 3: {'shape': 'cube'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 7311, # matching video frames: 833428
# add_predicate_object took time: 427.326s
# g1: [defaultdict(<class 'dict'>, {2: {'shape': 'cylinder'}, 3: {'shape': 'cube'}, 0: {'material': 'rubber'}, 1: {'color': 'green', 'material': 'metal'}}), defaultdict(<class 'dict'>, {})]
# # matching videos: 1429, # matching video frames: 126660
# add_predicate_attribute took time: 348.079s
# g1: [defaultdict(<class 'dict'>, {2: {'shape': 'cylinder'}, 3: {'shape': 'cube'}, 0: {'material': 'rubber'}, 1: {'color': 'green', 'material': 'metal'}}), defaultdict(<class 'dict'>, {1: {'sub_id': 2, 'obj_id': 3, 'rel_name': 'collision'}})]
# # matching videos: 783, # matching video frames: 1008
# add_predicate_relationship took time: 62.841s
# seqence of region graphs: ([defaultdict(<class 'dict'>, {0: {'shape': 'cylinder', 'material': 'rubber'}, 1: {'shape': 'sphere', 'color': 'purple', 'material': 'metal'}}), defaultdict(<class 'dict'>, {0: {'sub_id': 0, 'obj_id': 1, 'rel_name': 'collision'}})], [defaultdict(<class 'dict'>, {2: {'shape': 'cylinder'}, 3: {'shape': 'cube'}, 0: {'material': 'rubber'}, 1: {'color': 'green', 'material': 'metal'}}), defaultdict(<class 'dict'>, {1: {'sub_id': 2, 'obj_id': 3, 'rel_name': 'collision'}})])
# # matching videos: 1, # matching video segments: 1
# add_predicate_seq_of_region_graphs took time: 0.000s
# outputs: defaultdict(<class 'list'>, {7977: [[31, 41]]})
# visualize_outputs took time: 0.448s
# ```
