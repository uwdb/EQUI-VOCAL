# %%
import json
import numpy as np

# %%
# PATSQL
# open json file
queries = ["Conjunction(Near_1(o0, o1), BottomQuadrant(o0))", 
           "Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)", 
           "Far_3(o0, o1); Conjunction(Near_1(o0, o1), Behind(o0, o1))",
          "Far_3(o0, o1); Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
          "Conjunction(FrontOf(o0, o1), TopQuadrant(o0))",
           "Near_1(o0, o1); Far_3(o0, o1)", 
           "Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
           "Conjunction(Far_3(o0, o1), BottomQuadrant(o0)); Near_1(o0, o1)",
           "Conjunction(Far_3(o0, o1), LeftQuadrant(o0)); Conjunction(Near_1(o0, o1), LeftQuadrant(o0))"]
for query in queries:
    print(query)
    with open('/gscratch/balazinska/enhaoz/complex_event_video/src/quivr/outputs/without_duration-sampling_rate_4/stats/PATSQL/{}.json'.format(query)) as f:
        data = json.load(f)
    scores = data['score']
    runtimes = data['runtime']
    n_examples = list(range(12, 21)) + list(range(25, 51, 5))
    result_time = []
    result_examples = []
    for score_per_run, runtime_per_run in zip(scores, runtimes):
        for n_examples_per_run, score, runtime in zip(n_examples, score_per_run, runtime_per_run):
            if score > 0.9:
                result_time.append(runtime)
                result_examples.append(n_examples_per_run)
                break
    print(result_time)
    print("median:", np.median(result_time))
    print(result_examples)
    print("median:", np.median(result_examples))
# Out:
# Conjunction(Near_1(o0, o1), BottomQuadrant(o0))
# [2.052, 2.192, 1.331, 2.16, 1.598, 1.174, 1.725, 1.489, 0.257, 1.536, 0.227, 0.123, 0.196, 2.077, 1.225, 3.55, 1.198, 2.851, 2.013]
# median: 1.536
# [19, 12, 12, 20, 18, 12, 12, 25, 12, 12, 12, 12, 12, 18, 12, 35, 15, 30, 20]
# median: 12.0
# Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)
# []
# median: nan
# []
# median: nan
# Far_3(o0, o1); Conjunction(Near_1(o0, o1), Behind(o0, o1))
# [669.861, 156.592, 715.278, 449.102, 257.844, 491.368, 305.83, 664.532, 358.111, 1079.121, 628.719, 290.208, 166.292, 607.134, 583.925, 3208.975, 2198.704, 263.022]
# median: 537.6465
# [12, 12, 12, 12, 12, 12, 12, 13, 12, 12, 12, 12, 12, 12, 12, 35, 19, 12]
# median: 12.0
# Far_3(o0, o1); Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))
# []
# median: nan
# []
# median: nan
# Conjunction(FrontOf(o0, o1), TopQuadrant(o0))
# ...

# %%
# Quivr
queries = ["Conjunction(Near_1(o0, o1), BottomQuadrant(o0))", 
           "Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)", 
           "Far_3(o0, o1); Conjunction(Near_1(o0, o1), Behind(o0, o1))",
          "Far_3(o0, o1); Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
          "Conjunction(FrontOf(o0, o1), TopQuadrant(o0))",
           "Near_1(o0, o1); Far_3(o0, o1)", 
           "Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
           "Conjunction(Far_3(o0, o1), BottomQuadrant(o0)); Near_1(o0, o1)",
           "Conjunction(Far_3(o0, o1), LeftQuadrant(o0)); Conjunction(Near_1(o0, o1), LeftQuadrant(o0))"]
for query in queries:
    print(query)
    result_time = []
    result_examples = []
    for run_id in range(20):
        with open('/gscratch/balazinska/enhaoz/complex_event_video/outputs/without_duration-sampling_rate_4/stats/quivr_original_no_kleene/nip_2-nin_10-npred_5-n_nontrivial_None-n_trivial_None-depth_3-max_d_1-thread_1-lru_50000/{}-{}.json'.format(query, run_id)) as f:
            data = json.load(f)
        score_per_run = data['score_median']
        runtime_per_run = data['runtime']    
        n_examples = list(range(12, 51))
        found = False
        for n_examples_per_run, score, runtime in zip(n_examples, score_per_run, runtime_per_run):
            if score > 0.9:
                result_time.append(runtime)
                result_examples.append(n_examples_per_run)
                found = True
                break
        if not found:
            result_time.append(float('inf'))
            result_examples.append(float('inf'))
    print(result_time)
    print("median:", np.median(result_time))
    print(result_examples)
    print("median:", np.median(result_examples))
# Out:
# Conjunction(Near_1(o0, o1), BottomQuadrant(o0))
# [20.987818956375122, 14.499024391174316, 10.659619808197021, 12.043368101119995, 13.918242692947388, 9.772506713867188, 9.935197353363037, 8.017271041870117, 14.527686595916748, 11.949499368667603, 10.031770467758179, 12.218871355056763, 5.374963045120239, 14.156585693359375, 10.25174593925476, 9.237021446228027, 6.871602296829224, 14.528847694396973, 6.470705509185791, 9.190757513046265]
# median: 10.455682873725891
# [14, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 14, 12, 12, 12, 12, 12, 12]
# median: 12.0
# Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)
# ...

# %%
# VOCAL
queries = ["Conjunction(Near_1(o0, o1), BottomQuadrant(o0))", 
           "Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)", 
           "Far_3(o0, o1); Conjunction(Near_1(o0, o1), Behind(o0, o1))",
          "Far_3(o0, o1); Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
          "Conjunction(FrontOf(o0, o1), TopQuadrant(o0))",
           "Near_1(o0, o1); Far_3(o0, o1)", 
           "Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
           "Conjunction(Far_3(o0, o1), BottomQuadrant(o0)); Near_1(o0, o1)",
           "Conjunction(Far_3(o0, o1), LeftQuadrant(o0)); Conjunction(Near_1(o0, o1), LeftQuadrant(o0))"]
for query in queries:
    print(query)
    with open('/gscratch/balazinska/enhaoz/complex_event_video/src/quivr/outputs/without_duration-sampling_rate_4/stats/vocal_postgres-topk/{}.json'.format(query)) as f:
        data = json.load(f)
    scores = data['score_median']
    runtimes = data['runtime']
    n_examples = list(range(12, 21)) + list(range(25, 51, 5))
    result_time = []
    result_examples = []
    for score_per_run, runtime_per_run in zip(scores, runtimes):
        for n_examples_per_run, score, runtime in zip(n_examples, score_per_run, runtime_per_run):
            if score > 0.9:
                result_time.append(runtime)
                result_examples.append(n_examples_per_run)
                break
    print(result_time)
    print("median:", np.median(result_time))
    print(result_examples)
    print("median:", np.median(result_examples))
# Out:
# Conjunction(Near_1(o0, o1), BottomQuadrant(o0))
# [4.272643089294434, 3.3879973888397217, 3.248825788497925, 3.2579798698425293, 5.412799596786499, 3.192875623703003, 4.282007932662964, 2.3546576499938965, 3.5846126079559326, 8.30619478225708, 4.633955478668213, 4.080967426300049, 1.880990743637085, 4.644906997680664, 3.3555471897125244, 3.682884931564331, 2.8580782413482666, 4.126986026763916, 1.9012842178344727, 3.553313732147217]
# median: 3.5689631700515747
# [13, 12, 12, 12, 14, 12, 14, 12, 13, 14, 13, 14, 12, 14, 12, 13, 12, 14, 12, 13]
# median: 13.0
# Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)
# ...

# %%
##### Quivr
# normal trajectory pairs queries
queries = ["Conjunction(Near_1(o0, o1), BottomQuadrant(o0))", 
           "Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)", 
           "Far_3(o0, o1); Conjunction(Near_1(o0, o1), Behind(o0, o1))",
          "Far_3(o0, o1); Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
          "Conjunction(FrontOf(o0, o1), TopQuadrant(o0))",
           "Near_1(o0, o1); Far_3(o0, o1)", 
           "Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
           "Conjunction(Far_3(o0, o1), BottomQuadrant(o0)); Near_1(o0, o1)",
           "Conjunction(Far_3(o0, o1), LeftQuadrant(o0)); Conjunction(Near_1(o0, o1), LeftQuadrant(o0))"]
for query in queries:
    print(query)
    result_time = []
    result_examples = []
    for run_id in range(20):
        try:
            with open('/gscratch/balazinska/enhaoz/complex_event_video/outputs/trajectories_handwritten/stats/quivr_original_no_kleene/nip_2-nin_10-npred_5-n_nontrivial_None-n_trivial_None-depth_3-max_d_1-thread_1-lru_50000/{}-{}.json'.format(query, run_id)) as f:
                data = json.load(f)
            score_per_run = data['score_median']
            runtime_per_run = data['runtime']    
            n_examples = list(range(12, 51))
            found = False
            for n_examples_per_run, score, runtime in zip(n_examples, score_per_run, runtime_per_run):
                if score > 0.9:
                    result_time.append(runtime)
                    result_examples.append(n_examples_per_run)
                    found = True 
                    break
            if not found:
                result_time.append(float('inf'))
                result_examples.append(float('inf'))
        except Exception as err:
            result_time.append(float('inf'))
            result_examples.append(float('inf'))
            pass
    print(result_time)
    print("median:", np.median(result_time))
    print(result_examples)
    print("median:", np.median(result_examples))
# Out:
# Conjunction(Near_1(o0, o1), BottomQuadrant(o0))
# [9246.560101747513, 365.04523396492004, 9882.281459093094, 3247.126467227936, 8045.15016913414, inf, 6113.0986359119415, 10068.028459787369, 4682.07368850708, inf, 9958.63548374176, 7157.456639289856, 7297.705225467682, 4330.18049955368, 4521.080109119415, 11677.56479024887, 7988.57874751091, 4687.763639450073, 9399.159653425217, 890.0150527954102]
# median: 7643.141986489296
# [12, 12, 13, 13, 14, inf, 12, 12, 12, inf, 12, 12, 14, 13, 13, 14, 15, 15, 12, 12]
# median: 13.0
# Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)
# [9249.06307888031, inf, inf, inf, inf, inf, inf, 3940.1836795806885, inf, 3758.9567441940308, 7427.6705367565155, 13786.30495929718, 3336.4256892204285, 9358.506237983704, inf, 8034.3036642074585, 899.2591898441315, inf, 7394.679805517197, 12302.78551030159]
# median: 13044.545234799385
# [18, inf, inf, inf, inf, inf, inf, 19, inf, 19, 18, 20, 14, 17, inf, 20, 15, inf, 18, 21]
# median: 20.5
# ...

# %%
# VOCAL
queries = ["Conjunction(Near_1(o0, o1), BottomQuadrant(o0))", 
           "Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)", 
           "Far_3(o0, o1); Conjunction(Near_1(o0, o1), Behind(o0, o1))",
          "Far_3(o0, o1); Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
          "Conjunction(FrontOf(o0, o1), TopQuadrant(o0))",
           "Near_1(o0, o1); Far_3(o0, o1)", 
           "Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
           "Conjunction(Far_3(o0, o1), BottomQuadrant(o0)); Near_1(o0, o1)",
           "Conjunction(Far_3(o0, o1), LeftQuadrant(o0)); Conjunction(Near_1(o0, o1), LeftQuadrant(o0))"]
for query in queries:
    print(query)
    with open('/gscratch/balazinska/enhaoz/complex_event_video/src/quivr/outputs/trajectories_handwritten/stats/vocal_postgres-topk/{}.json'.format(query)) as f:
        data = json.load(f)
    scores = data['score_median']
    runtimes = data['runtime']
    n_examples = list(range(12, 21)) + list(range(25, 51, 5))
    result_time = []
    result_examples = []
    for score_per_run, runtime_per_run in zip(scores, runtimes):
        for n_examples_per_run, score, runtime in zip(n_examples, score_per_run, runtime_per_run):
            if score > 0.9:
                result_time.append(runtime)
                result_examples.append(n_examples_per_run)
                break
    print(result_time)
    print("median:", np.median(result_time))
    print(result_examples)
    print("median:", np.median(result_examples))
# Out:
# Conjunction(Near_1(o0, o1), BottomQuadrant(o0))
# [71.84864568710327, 47.82487344741821, 115.98501014709473, 103.58830070495605, 60.259549379348755, 97.58536148071289, 47.362905740737915, 79.37504959106445, 80.97842693328857, 40.60097336769104, 55.878036975860596, 51.12479829788208, 83.90535950660706, 158.50620985031128, 138.57031440734863, 66.71254849433899, 113.68530178070068, 59.93017601966858, 60.72352743148804, 94.13949275016785]
# median: 75.61184763908386
# [14, 12, 19, 18, 13, 16, 12, 12, 14, 12, 12, 12, 14, 19, 19, 14, 19, 13, 12, 16]
# median: 14.0
# Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)
# ...

# %%
# OLD: number of queries explored & number of predictions
# Quivr 
queries = ["Conjunction(Near_1(o0, o1), BottomQuadrant(o0))", 
           "Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)", 
           "Far_3(o0, o1); Conjunction(Near_1(o0, o1), Behind(o0, o1))",
          "Far_3(o0, o1); Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))"]
for query in queries:
    print(query)
    queries_count_list = []
    predictions_count_list = []
    for run_id in range(20):
        try:
            with open('/gscratch/balazinska/enhaoz/complex_event_video/src/quivr/outputs/trajectories_handwritten/quivr_original_no_kleene/nip_2-nin_10-npred_5-n_nontrivial_None-n_trivial_None-depth_3-max_d_1-thread_1-lru_50000/{}-{}.log'.format(query, run_id)) as f:
                lines = [line.rstrip() for line in f]
            queries_count = int(lines[-2].split(" ")[-1])
            predictions_count = int(lines[-1].split(" ")[-1])
            runtime = float(lines[-3].split(" ")[-1])
            queries_count_list.append(queries_count)
            predictions_count_list.append(predictions_count/runtime)
        except Exception as err:
            pass
    print(queries_count_list)
    print("queries_count median:", np.median(queries_count_list))
    print(predictions_count_list)
    print("predictions_count median:", np.median(predictions_count_list))
# Out:
# Conjunction(Near_1(o0, o1), BottomQuadrant(o0))
# [269815, 26728, 398093, 113842, 293416, 214689, 336565, 130084, 191346, 250121, 162625, 404844, 72250]
# queries_count median: 214689.0
# [267.19502701800104, 209.53581310753916, 185.5034592073348, 93.3744808292227, 108.99971481789112, 189.41535473479152, 181.50038511311456, 156.32961774415116, 166.44159270019904, 142.0107574748369, 179.12149832133517, 181.88598309420433, 168.00259101261594]
# predictions_count median: 179.12149832133517
# Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)
# [400729, 186333, 124847, 290496, 123033, 245112, 185610, 33356, 271446]
# queries_count median: 186333.0
# [137.6292711261947, 204.5780719687747, 186.8822596921055, 176.49431363532324, 106.20219319814983, 198.45537475606076, 100.90142375319876, 160.9666331559278, 188.4536337357442]
# predictions_count median: 176.49431363532324
# Far_3(o0, o1); Conjunction(Near_1(o0, o1), Behind(o0, o1))
# ...

# %%
# NEW: number of queries explored & number of predictions
# Quivr 
queries = ["Conjunction(Near_1(o0, o1), BottomQuadrant(o0))", 
           "Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)", 
           "Far_3(o0, o1); Conjunction(Near_1(o0, o1), Behind(o0, o1))",
          "Far_3(o0, o1); Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
          "Conjunction(FrontOf(o0, o1), TopQuadrant(o0))",
           "Near_1(o0, o1); Far_3(o0, o1)", 
           "Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
           "Conjunction(Far_3(o0, o1), BottomQuadrant(o0)); Near_1(o0, o1)",
           "Conjunction(Far_3(o0, o1), LeftQuadrant(o0)); Conjunction(Near_1(o0, o1), LeftQuadrant(o0))"]
for query in queries:
    print(query)
    queries_count_list = []
    predictions_count_list = []
    for run_id in range(20):
        try:
            with open('/gscratch/balazinska/enhaoz/complex_event_video/outputs/trajectories_handwritten/stats/quivr_original_no_kleene/nip_2-nin_10-npred_5-n_nontrivial_None-n_trivial_None-depth_3-max_d_1-thread_1-lru_50000/{}-{}.json'.format(query, run_id)) as f:
                data = json.load(f)
            score_per_run = data['score_median']
            runtime_per_run = data['runtime']    
            n_examples = list(range(12, 51))
            for n_examples_per_run, score, runtime in zip(n_examples, score_per_run, runtime_per_run):
                if score > 0.9:
                    with open('/gscratch/balazinska/enhaoz/complex_event_video/outputs/trajectories_handwritten/quivr_original_no_kleene/nip_2-nin_10-npred_5-n_nontrivial_None-n_trivial_None-depth_3-max_d_1-thread_1-lru_50000/{}-{}.log'.format(query, run_id)) as f:
                        lines = []
                        for line in f:
                            stripped_line = line.rstrip()
                            if "[Step {}]".format(n_examples_per_run-12+1) in stripped_line:
                                break
                            lines.append(stripped_line)
                    queries_count = int(lines[-2].split(" ")[-1])
                    predictions_count = int(lines[-1].split(" ")[-1])
                    queries_count_list.append(queries_count)
                    predictions_count_list.append(predictions_count/runtime) 
                    break
        except Exception as err:
            pass
    print(queries_count_list)
    print("queries_count median:", np.median(queries_count_list))
    print(predictions_count_list)
    print("predictions_count median:", np.median(predictions_count_list))
# Out:
# Conjunction(Near_1(o0, o1), BottomQuadrant(o0))
# [290630, 26728, 398093, 113842, 208356, 304977, 381294, 214689, 336565, 241525, 218970, 130084, 191390, 250121, 226526, 213282, 422276, 72250]
# queries_count median: 222748.0
# [121.59419152940049, 293.1225778180759, 164.05068067640107, 172.5393222760092, 148.74029382210875, 156.87494298984745, 145.87920622852693, 153.49117673309198, 169.3932871379856, 129.69411437358028, 153.8236973565974, 147.3033283637355, 138.08691395242656, 128.872759606237, 151.16919268978523, 216.4351870178812, 186.5333779452382, 280.3806511094628]
# predictions_count median: 153.6574370448447
# Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)
# [432598, 186333, 135825, 290496, 356741, 123033, 245112, 185610, 33356, 271446, 490275]
# queries_count median: 245112.0
# ...

# %%
# number of queries explored & number of predictions
# VOCAL
queries = ["Conjunction(Near_1(o0, o1), BottomQuadrant(o0))", 
           "Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)", 
           "Far_3(o0, o1); Conjunction(Near_1(o0, o1), Behind(o0, o1))",
          "Far_3(o0, o1); Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
          "Conjunction(FrontOf(o0, o1), TopQuadrant(o0))",
           "Near_1(o0, o1); Far_3(o0, o1)", 
           "Conjunction(Conjunction(Near_1(o0, o1), LeftQuadrant(o0)), Behind(o0, o1))",
           "Conjunction(Far_3(o0, o1), BottomQuadrant(o0)); Near_1(o0, o1)",
           "Conjunction(Far_3(o0, o1), LeftQuadrant(o0)); Conjunction(Near_1(o0, o1), LeftQuadrant(o0))"]
for query in queries:
    print(query)
    with open('/gscratch/balazinska/enhaoz/complex_event_video/src/quivr/outputs/trajectories_handwritten/stats/vocal_postgres-topk/{}.json'.format(query)) as f:
        data = json.load(f)
    scores = data['score_median']
    runtimes = data['runtime']
    n_examples = list(range(12, 21)) + list(range(25, 51, 5))
    queries_count_list = []
    predictions_count_list = []
    for run_id, (score_per_run, runtime_per_run) in enumerate(zip(scores, runtimes)):
        for n_examples_per_run, score, runtime in zip(n_examples, score_per_run, runtime_per_run):
            if score > 0.9:
                with open('/gscratch/balazinska/enhaoz/complex_event_video/src/quivr/outputs/trajectories_handwritten/vocal_postgres-topk/nip_2-nin_10-npred_5-depth_3-max_d_1-nvars_2-bw_10-pool_size_100-k_100-budget_{}-thread_1-lru_None-lambda_0.01/{}-{}.log'.format(n_examples_per_run, query, run_id)) as f:
                    lines = [line.rstrip() for line in f]
                queries_count = int(lines[-3].split(" ")[-1])
                predictions_count = int(lines[-2].split(" ")[-1])
                queries_count_list.append(queries_count)
                predictions_count_list.append(predictions_count/runtime) 
                break
    print(queries_count_list)
    print("queries_count median:", np.median(queries_count_list))
    print(predictions_count_list)
    print("predictions_count median:", np.median(predictions_count_list))
# Out:
# Conjunction(Near_1(o0, o1), BottomQuadrant(o0))
# [1111, 1087, 1131, 1148, 1158, 1106, 1065, 1205, 1118, 1123, 1072, 1168, 1157, 1123, 1064, 1094, 1132, 1088, 1169, 1127]
# queries_count median: 1123.0
# [619.2183523368192, 418.2760676197858, 784.515170405227, 781.6423230130865, 566.6487776906941, 603.7893297310309, 409.43433889277827, 304.47854992862494, 546.318342741403, 611.8079922627392, 384.40863642506616, 402.07493592892206, 544.1607099771106, 581.2327484645806, 654.8516569952138, 631.3504872861225, 773.5916483702363, 522.6415485534429, 359.8605174024969, 632.380717814032]
# predictions_count median: 573.9407630776374
# Far_3(o0, o1); Near_1(o0, o1); Far_3(o0, o1)
# [1033, 1083, 1046, 1107, 1081, 1078, 1049, 1053, 1121, 1069, 1129, 1073, 1078, 1077, 1066, 1056, 1014, 1043, 1051, 1076]
# queries_count median: 1071.0
# ...

# %%
# VOCAL
# TQ1D-TQ3D
queries = ["Duration(Far_3(o0, o1), 5); Near_1(o0, o1); Far_3(o0, o1)",
           "Duration(LeftOf(o0, o1), 5); Conjunction(Near_1(o0, o1), TopQuadrant(o0)); Duration(RightOf(o0, o1), 5)",
           "Duration(Conjunction(FrontOf(o0, o1), LeftQuadrant(o0)), 15); Duration(Conjunction(Conjunction(LeftQuadrant(o0), RightOf(o0, o1)), TopQuadrant(o0)), 5)"
          ]
for query in queries:
    print(query)
    with open('/gscratch/balazinska/enhaoz/complex_event_video/src/quivr/outputs/trajectories_duration/stats/vocal_postgres-topk/{}.json'.format(query)) as f:
        data = json.load(f)
    scores = data['score_median']
    runtimes = data['runtime']
    n_examples = list(range(12, 21)) + list(range(25, 51, 5))
    result_time = []
    result_examples = []
    for run_id, (score_per_run, runtime_per_run) in enumerate(zip(scores, runtimes)):
        for n_examples_per_run, score, runtime in zip(n_examples, score_per_run, runtime_per_run):
            if score > 0.9:
                result_time.append(runtime)
                result_examples.append(n_examples_per_run)
                break
        if len(result_time) == run_id:
            result_time.append(9999)
            result_examples.append(9999)
    print(result_time)
    print("median:", np.median(result_time))
    print(result_examples)
    print("median:", np.median(result_examples))
# Out:
# Duration(Far_3(o0, o1), 5); Near_1(o0, o1); Far_3(o0, o1)
# [252.60693097114563, 77.06837224960327, 9999, 254.82836842536926, 9999, 339.35798931121826, 373.4712975025177, 194.10114884376526, 216.35033893585205, 200.9565920829773, 204.17328000068665, 144.6939606666565, 9999, 116.83813095092773, 236.90996074676514, 96.47389531135559, 268.289715051651, 66.07707905769348, 188.9521780014038, 229.8224868774414]
# median: 223.08641290664673
# [45, 15, 9999, 40, 9999, 30, 50, 30, 40, 40, 35, 25, 9999, 25, 40, 18, 50, 16, 40, 40]
# median: 40.0
# Duration(LeftOf(o0, o1), 5); Conjunction(Near_1(o0, o1), TopQuadrant(o0)); Duration(RightOf(o0, o1), 5)
# ...
